# %%
import pandas as pd
import numpy as np

# %%
l1=[28445,14303,9942,19503,20100,11325,11594,17666,8922,8699]
l=['SOUTHERN','BAYVIEW','TENDERLOIN','MISSION','NORTHERN','TARAVAL','INGLESIDE','CENTRAL','RICHMOND','PARK']
data=pd.DataFrame()

# %%
data['Neighborhood']=l
data['Count']=l1

# %%
data.head(10)
# Out:
#   Neighborhood  Count
# 0     SOUTHERN  28445
# 1      BAYVIEW  14303
# 2   TENDERLOIN   9942
# 3      MISSION  19503
# 4     NORTHERN  20100
# 5      TARAVAL  11325
# 6    INGLESIDE  11594
# 7      CENTRAL  17666
# 8     RICHMOND   8922
# 9         PARK   8699

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed and imported!')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
# ...

# %%
# !conda install -c anaconda xlrd --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - xlrd
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.1.1   |                0         132 KB  anaconda
#     openssl-1.1.1g             |       h7b6447c_0         3.8 MB  anaconda
#     xlrd-1.2.0                 |             py_0         108 KB  anaconda
#     certifi-2020.4.5.1         |           py36_0         159 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         4.2 MB
#
# The following packages will be UPDATED:
#
#     certifi:         2020.4.5.1-py36h9f0ad1d_0 conda-forge --> 2020.4.5.1-py36_0 anaconda
#     openssl:         1.1.1g-h516909a_0         conda-forge --> 1.1.1g-h7b6447c_0 anaconda
# ...

# %%
# San Francisco latitude and longitude values
latitude = 37.77
longitude = -122.42

# %%
# create map and display it
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# display the map of San Francisco
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.
credentials_1 = {
    'IAM_SERVICE_ID': 'iam-ServiceId-23ca7c0a-a96d-4d45-ab90-eb2fc554fec8',
    'IBM_API_KEY_ID': 'I05ojXvgmMNdFRW8bhmwmRW2-4gDHD2Uuzuudp29e0zK',
    'ENDPOINT': 'https://s3.eu-geo.objectstorage.service.networklayer.com',
    'IBM_AUTH_ENDPOINT': 'https://iam.eu-gb.bluemix.net/oidc/token',
    'BUCKET': 'pythonbasicsfordatascience-donotdelete-pr-krnhqrvpelffpd',
    'FILE': 'san-francisco (1).geojson'
}

# %%
geo_data=credentials_1['FILE']

# %%
df_san=data.copy()

# %%
df_san.head(10)
# Out:
#   Neighborhood  Count
# 0     SOUTHERN  28445
# 1      BAYVIEW  14303
# 2   TENDERLOIN   9942
# 3      MISSION  19503
# 4     NORTHERN  20100
# 5      TARAVAL  11325
# 6    INGLESIDE  11594
# 7      CENTRAL  17666
# 8     RICHMOND   8922
# 9         PARK   8699

# %%
sanfran_map.choropleth(
geo_data=credentials_1,
data=df_san,
columns=['Neighborhood','Count'],
key_on='feature.properties.DISTRICT',
fill_color='YlOrRd',
fill_opacity=0.7, 
line_opacity=0.2,
legend_name='Crime in San Francisco'
)

sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
